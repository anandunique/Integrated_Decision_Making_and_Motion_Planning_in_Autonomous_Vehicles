# %%
# Given data as a list of strings
raw_data = """
Step,Total Reward,Collisions,Safe Gaps
45,-1368,6,10
42,-1266,6,12
44,-1500,7,14
49,-1432,5,16
36,-829,3,11
43,-976,2,16
56,-172,1,2
57,-274,1,4
31,-631,2,9
36,-172,1,2
118,-172,1,2
69,-1047,7,8
34,-274,1,4
31,-427,2,5
31,-478,2,6
31,-478,2,6
32,-324,2,3
44,-1126,4,15
43,-170,1,2
38,-172,1,2
53,-223,1,3
52,-374,3,2
42,-478,1,8
43,-223,1,3
34,-172,1,2
37,-172,1,2
34,-579,2,8
33,-427,1,7
34,-579,2,8
53,-223,1,3
45,-631,3,2
40,-172,1,2
35,-426,2,5
34,-579,2,8
34,-732,2,11
144,-172,1,2
40,-172,1,2
40,-172,1,2
53,-167,1,3
40,-172,1,2
40,-172,1,2
51,-155,1,2
40,-172,1,2
31,-189,2,3
40,-172,1,2
53,-223,1,3
40,-172,1,2
40,-172,1,2
40,-172,1,2
40,-172,1,2
"""

# Split the data into lines and extract the Total Reward column
lines = raw_data.strip().split("\n")[1:]  # Exclude header row
total_rewards_1 = [int(line.split(",")[1]) for line in lines]  # Extract second column

collision_1 = [int(line.split(",")[2]) for line in lines]  # Extract third column
collision_1 = [-100 * count for count in collision_1]


safety_gap_1 = [int(line.split(",")[3]) for line in lines]
safety_gap_1 = [-50 * count for count in safety_gap_1]

print("Total Rewards:", total_rewards_1)
print("collisons:",collision_1)
print(safety_gap_1)
# Out:
# Total Rewards: [-1368, -1266, -1500, -1432, -829, -976, -172, -274, -631, -172, -172, -1047, -274, -427, -478, -478, -324, -1126, -170, -172, -223, -374, -478, -223, -172, -172, -579, -427, -579, -223, -631, -172, -426, -579, -732, -172, -172, -172, -167, -172, -172, -155, -172, -189, -172, -223, -172, -172, -172, -172]
# collisons: [-600, -600, -700, -500, -300, -200, -100, -100, -200, -100, -100, -700, -100, -200, -200, -200, -200, -400, -100, -100, -100, -300, -100, -100, -100, -100, -200, -100, -200, -100, -300, -100, -200, -200, -200, -100, -100, -100, -100, -100, -100, -100, -100, -200, -100, -100, -100, -100, -100, -100]
# [-500, -600, -700, -800, -550, -800, -100, -200, -450, -100, -100, -400, -200, -250, -300, -300, -150, -750, -100, -100, -150, -100, -400, -150, -100, -100, -400, -350, -400, -150, -100, -100, -250, -400, -550, -100, -100, -100, -150, -100, -100, -100, -100, -150, -100, -150, -100, -100, -100, -100]

# %%
import matplotlib.pyplot as plt



# Number of episodes (x-axis)
episodes = list(range(1, 51))  # Episodes 1 to 50

# Create the plot
plt.figure(figsize=(6, 4))

# Plot the total rewards
plt.plot(episodes, total_rewards_1, 'b-', label='Total Rewards')  # Blue line for total rewards

# Set the plot title and labels
plt.title("Episodes vs Rewards for DQN + MPC")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Total Rewards")  # y-axis label


# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(6, 4))

# Plot the total rewards
plt.plot(episodes, collision_1, 'b-', label='Reward for Collisions')  # Blue line for total rewards

# Set the plot title and labels
plt.title("Episodes vs No.of.collisions")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Reward for Collisions")  # y-axis label


# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(6, 4))

# Plot the total rewards
plt.plot(episodes, safety_gap_1, 'b-', label='Reward for Safety')  # Blue line for total rewards

# Set the plot title and labels
plt.title("Episodes vs Minimum safety gap maintenance")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Reward for Safety")  # y-axis label


# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### DDQN Graph Plotting

# %%
# Given data as a list of strings
raw_data = """
Step,Total Reward,Collisions,Safe Gaps
1,-770,3,10
2,-833,3,11
3,-429,1,7
4,-631,2,9
5,-478,2,6
6,-579,2,8
7,-871,5,8
8,-477,2,6
9,-625,3,7
10,-478,2,6
11,-478,2,6
12,-732,2,11
13,-630,2,9
14,-479,1,8
15,-478,2,6
16,-630,2,9
17,-478,2,6
18,-476,3,4
19,-478,2,6
20,-478,2,6
21,-478,2,6
22,-579,2,8
23,-631,2,9
24,-478,2,6
25,-478,2,6
26,-274,1,4
27,-631,2,9
28,-731,3,9
29,-680,3,8
30,-172,1,2
31,-631,2,9
32,-172,1,2
33,-640,3,5
34,-689,3,7
35,-278,2,3
35,-291,2,4
36,-583,3,4
37,-546,3,5
38,-556,4,3
33,-478,2,6
34,-478,2,6
35,-478,2,6
35,-480,3,5
36,-478,2,6
36,-478,2,6
36,-478,2,6
18,-476,3,4
36,-478,2,6
36,-478,2,6
36,-480,2,7

"""

# Split the data into lines and extract the Total Reward column
lines = raw_data.strip().split("\n")[1:]  # Exclude header row

total_rewards_2 = [int(line.split(",")[1]) for line in lines]  # Extract second column

collision_2 = [int(line.split(",")[2]) for line in lines]  # Extract third column
collision_2 = [-100 * count for count in collision_2]


safety_gap_2 = [int(line.split(",")[3]) for line in lines]
safety_gap_2 = [-50 * count for count in safety_gap_2]

print("Total Rewards:", total_rewards_2)
print("collisons:",collision_2)
print("safety gap:",safety_gap_2)
# Out:
# Total Rewards: [-770, -833, -429, -631, -478, -579, -871, -477, -625, -478, -478, -732, -630, -479, -478, -630, -478, -476, -478, -478, -478, -579, -631, -478, -478, -274, -631, -731, -680, -172, -631, -172, -640, -689, -278, -291, -583, -546, -556, -478, -478, -478, -480, -478, -478, -478, -476, -478, -478, -480]
# collisons: [-300, -300, -100, -200, -200, -200, -500, -200, -300, -200, -200, -200, -200, -100, -200, -200, -200, -300, -200, -200, -200, -200, -200, -200, -200, -100, -200, -300, -300, -100, -200, -100, -300, -300, -200, -200, -300, -300, -400, -200, -200, -200, -300, -200, -200, -200, -300, -200, -200, -200]
# safety gap: [-500, -550, -350, -450, -300, -400, -400, -300, -350, -300, -300, -550, -450, -400, -300, -450, -300, -200, -300, -300, -300, -400, -450, -300, -300, -200, -450, -450, -400, -100, -450, -100, -250, -350, -150, -200, -200, -250, -150, -300, -300, -300, -250, -300, -300, -300, -200, -300, -300, -350]

# %%
# Number of episodes (x-axis)
episodes = list(range(1, 51))  # Episodes 1 to 50

# Create the plot
plt.figure(figsize=(6,4))

# Plot the total rewards
plt.plot(episodes, total_rewards_2, 'r-', label='Total Rewards')  # Blue line for total rewards

# Set the plot title and labels
plt.title("Episodes vs Rewards for DDQN + MPC")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Total Rewards")  # y-axis label


# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(6, 4))

# Plot the total rewards
plt.plot(episodes, collision_2, 'r-', label='Reward for Collisions')  # Blue line for total rewards

# Set the plot title and labels
plt.title("Episodes vs No.of.collisions")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Reward for Collisions")  # y-axis label


# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
# Create the plot
plt.figure(figsize=(6, 4))

# Plot the total rewards
plt.plot(episodes, safety_gap_2, 'r-', label='Reward for Safety')  # Blue line for total rewards

# Set the plot title and labels
plt.title("Episodes vs Minimum safety gap maintenance")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Reward for Safety")  # y-axis label


# Add a grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### Combining the graphs

# %%
import matplotlib.pyplot as plt

# Example data for DQN and DDQN
episodes = list(range(1, 51))  # Episodes 1 to 50

# Create a new plot
plt.figure(figsize=(10, 6))

# Plot DQN total rewards in blue
plt.plot(episodes, total_rewards_1, 'b-', label='DQN Total Rewards')  # Blue line for DQN

# Plot DDQN total rewards in red
plt.plot(episodes, total_rewards_2, 'r-', label='DDQN Total Rewards')  # Red line for DDQN

# Set the plot title and labels
plt.title("Episodes vs Rewards for DQN + DDQN")  # Graph title
plt.xlabel("Episodes")  # x-axis label
plt.ylabel("Total Rewards")  # y-axis label

# Add a grid for better readability
plt.grid(True)

# Add a legend to distinguish between DQN and DDQN
plt.legend()

# Show the plot
plt.show()
